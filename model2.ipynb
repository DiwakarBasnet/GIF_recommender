# %% [markdown]
# <a href="https://colab.research.google.com/github/DiwakarBasnet/GIF_recommender/blob/main/model2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
BATCH_SIZE = 32      # Number of training samples to work through before model's internal parameters are upadted
IMAGE_SIZE = 64      # Size of image
CHANNELS = 3         # RGB channels
EPOCHS = 50          # Number of passes of the entire training dataset

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load dataset from kaggle

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
# allocate required permission for file
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d msambare/fer2013
# Out:
# Downloading fer2013.zip to /content
#  71% 43.0M/60.3M [00:00<00:00, 64.4MB/s]
# 100% 60.3M/60.3M [00:00<00:00, 80.6MB/s]

# %%
! unzip fer2013.zip &> /dev/null

# %% [markdown]
# # Train test split

# %%
ds = tf.keras.preprocessing.image_dataset_from_directory(
    "./train",                               # directory
    labels = "inferred",                     # labels are generated from directory structure
    label_mode = "int",                      # labels are encoded as integer
    batch_size = BATCH_SIZE,                 # size of batches data
    image_size = (IMAGE_SIZE, IMAGE_SIZE),   # size to resize images after they are read from disk
    shuffle = True,                          # if false, sorts the data in alphanumeric order
    seed = 123                               # random seed for shuffling and transformation    
)
# Out:
# Found 28709 files belonging to 7 classes.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "./test",
    labels = "inferred",
    label_mode = "int",
    batch_size = BATCH_SIZE,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    shuffle = True,
    seed = 123
)
# Out:
# Found 7178 files belonging to 7 classes.

# %%
ds_size = len(ds)
train_size = int(0.70 * ds_size)     # train = 0.70 part of ds
val_size = int(0.30 * ds_size)       # validation = 0.30 part of ds

# %%
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size).take(val_size)

# %% [markdown]
# # Data Visualization

# %%
class_names = ds.class_names
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
plt.figure(figsize = (10, 10))
for image_batch, label_batch in ds.take(1):             # takes 1 batch of tf_dataset
  for i in range(12):
    ax = plt.subplot(3,4,i+1)                           # r:3, c:4, id:i+1
    plt.imshow(image_batch[i].numpy().astype("uint8"))  # .numpy() = converts tensor to numpy array
                                                        # .astype("uint8") = converts float to int
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

# %% [markdown]
# # Preprocessing

# %%
# tensorflow data input pipeline:
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)   # .cache() = reads image from disk and puts it in memory
                                                                                     # when needed later, which improves performance of pipeline
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)       # .shuffle(1000) = shuffles 1000th tensor along dimension 0

test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)     # .prefetch() = if GPU is busy trainig, it loads next set 
                                                                                     # batch from disk and improves performance

# %%
resize_and_rescale = tf.keras.Sequential([
          tf.keras.layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
          tf.keras.layers.experimental.preprocessing.Rescaling(1.0/63)
])

# %%
# data_augmentation = tf.keras.Sequential([
#           tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
#           tf.keras.layers.experimental.preprocessing.RandomRotation(0.2)
# ])

# %% [markdown]
# # Build and train model

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

model = models.Sequential([
            resize_and_rescale,
            #data_augmentation,

            # 1st convolution layer
            layers.Conv2D(64, (3,3), activation='relu', input_shape=input_shape),
            layers.MaxPool2D((2,2)),
            layers.Dropout(0.5),

            # 2nd convolution layer
            layers.Conv2D(64, (3,3), activation='relu'),
            layers.MaxPool2D((2,2)),
            layers.Dropout(0.5),

            # 3rd convolution layer
            layers.Conv2D(128, (3,3), activation='relu'),
            layers.MaxPool2D((2,2)),

            layers.Flatten(),

            layers.Dense(1024, activation='relu'),
            layers.Dropout(0.2),
            
            layers.Dense(7, activation='softmax')
])

model.build(input_shape = input_shape)        # model.build is required by api

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 64, 64, 3)           0
#
#  conv2d (Conv2D)             (32, 62, 62, 64)          1792
#
#  max_pooling2d (MaxPooling2D  (32, 31, 31, 64)         0
#  )
#
#  dropout (Dropout)           (32, 31, 31, 64)          0
#
#  conv2d_1 (Conv2D)           (32, 29, 29, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (32, 14, 14, 64)          0
#
#  conv2d_2 (Conv2D)           (32, 12, 12, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (32, 6, 6, 128)          0
#  2D)
#
#  flatten (Flatten)           (32, 4608)                0
#
#  dense (Dense)               (32, 1024)                4719616
#
#  dropout_2 (Dropout)         (32, 1024)                0
#
#  dense_1 (Dense)             (32, 7)                   7175
#
# =================================================================
# Total params: 4,839,367
# Trainable params: 4,839,367
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(),    # when labels in dataset is inferred use SparseCategoricalCrossentropy()
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,                # 1 shows progress bar
    validation_data = val_ds,
    shuffle = True
)

# Saving the  model to  use it later on
fer_json = model.to_json()
with open("drive/MyDrive/Models/model.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("drive/MyDrive/Models/model.h5")
# Out:
# Epoch 1/50
# 628/628 [==============================] - 29s 21ms/step - loss: 1.8697 - accuracy: 0.2577 - val_loss: 1.7446 - val_accuracy: 0.3120
# Epoch 2/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.6540 - accuracy: 0.3463 - val_loss: 1.5814 - val_accuracy: 0.3887
# Epoch 3/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.5651 - accuracy: 0.3889 - val_loss: 1.5474 - val_accuracy: 0.4076
# Epoch 4/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.4865 - accuracy: 0.4251 - val_loss: 1.4963 - val_accuracy: 0.4404
# Epoch 5/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.4210 - accuracy: 0.4521 - val_loss: 1.3625 - val_accuracy: 0.4794
# Epoch 6/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.3497 - accuracy: 0.4833 - val_loss: 1.3308 - val_accuracy: 0.4922
# Epoch 7/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.2859 - accuracy: 0.5110 - val_loss: 1.3312 - val_accuracy: 0.4959
# Epoch 8/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.2276 - accuracy: 0.5371 - val_loss: 1.3085 - val_accuracy: 0.5098
# Epoch 9/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.1652 - accuracy: 0.5555 - val_loss: 1.2957 - val_accuracy: 0.5143
# Epoch 10/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.0923 - accuracy: 0.5921 - val_loss: 1.2833 - val_accuracy: 0.5261
# Epoch 11/50
# 628/628 [==============================] - 7s 11ms/step - loss: 1.0250 - accuracy: 0.6172 - val_loss: 1.2815 - val_accuracy: 0.5308
# Epoch 12/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.9523 - accuracy: 0.6489 - val_loss: 1.3002 - val_accuracy: 0.5396
# Epoch 13/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.8799 - accuracy: 0.6745 - val_loss: 1.3262 - val_accuracy: 0.5390
# Epoch 14/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.8010 - accuracy: 0.7062 - val_loss: 1.3607 - val_accuracy: 0.5372
# Epoch 15/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.7143 - accuracy: 0.7366 - val_loss: 1.4411 - val_accuracy: 0.5347
# Epoch 16/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.6761 - accuracy: 0.7539 - val_loss: 1.4614 - val_accuracy: 0.5343
# Epoch 17/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.6308 - accuracy: 0.7695 - val_loss: 1.5016 - val_accuracy: 0.5270
# Epoch 18/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.5766 - accuracy: 0.7916 - val_loss: 1.5572 - val_accuracy: 0.5314
# Epoch 19/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.5429 - accuracy: 0.8080 - val_loss: 1.5525 - val_accuracy: 0.5297
# Epoch 20/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.5118 - accuracy: 0.8176 - val_loss: 1.6661 - val_accuracy: 0.5244
# Epoch 21/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.4624 - accuracy: 0.8368 - val_loss: 1.7530 - val_accuracy: 0.5225
# Epoch 22/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.4544 - accuracy: 0.8381 - val_loss: 1.7574 - val_accuracy: 0.5290
# Epoch 23/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.4298 - accuracy: 0.8506 - val_loss: 1.7402 - val_accuracy: 0.5268
# Epoch 24/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3943 - accuracy: 0.8611 - val_loss: 1.7941 - val_accuracy: 0.5312
# Epoch 25/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3770 - accuracy: 0.8656 - val_loss: 1.7821 - val_accuracy: 0.5344
# Epoch 26/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3527 - accuracy: 0.8758 - val_loss: 1.8035 - val_accuracy: 0.5321
# Epoch 27/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3432 - accuracy: 0.8813 - val_loss: 1.8802 - val_accuracy: 0.5289
# Epoch 28/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3386 - accuracy: 0.8845 - val_loss: 1.9452 - val_accuracy: 0.5258
# Epoch 29/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3381 - accuracy: 0.8831 - val_loss: 2.0472 - val_accuracy: 0.5321
# Epoch 30/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3139 - accuracy: 0.8936 - val_loss: 2.0538 - val_accuracy: 0.5263
# Epoch 31/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3154 - accuracy: 0.8921 - val_loss: 2.1027 - val_accuracy: 0.5253
# Epoch 32/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.3154 - accuracy: 0.8932 - val_loss: 1.9945 - val_accuracy: 0.5231
# Epoch 33/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2894 - accuracy: 0.9042 - val_loss: 2.1381 - val_accuracy: 0.5286
# Epoch 34/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2790 - accuracy: 0.9066 - val_loss: 2.2589 - val_accuracy: 0.5271
# Epoch 35/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2797 - accuracy: 0.9052 - val_loss: 2.1875 - val_accuracy: 0.5336
# Epoch 36/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2646 - accuracy: 0.9091 - val_loss: 2.1697 - val_accuracy: 0.5217
# Epoch 37/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2595 - accuracy: 0.9146 - val_loss: 2.2396 - val_accuracy: 0.5252
# Epoch 38/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2506 - accuracy: 0.9176 - val_loss: 2.2401 - val_accuracy: 0.5286
# Epoch 39/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2430 - accuracy: 0.9171 - val_loss: 2.2446 - val_accuracy: 0.5259
# Epoch 40/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2437 - accuracy: 0.9193 - val_loss: 2.2791 - val_accuracy: 0.5312
# Epoch 41/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2538 - accuracy: 0.9166 - val_loss: 2.1800 - val_accuracy: 0.5306
# Epoch 42/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2317 - accuracy: 0.9243 - val_loss: 2.2094 - val_accuracy: 0.5217
# Epoch 43/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2317 - accuracy: 0.9225 - val_loss: 2.3089 - val_accuracy: 0.5265
# Epoch 44/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2339 - accuracy: 0.9226 - val_loss: 2.4089 - val_accuracy: 0.5287
# Epoch 45/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2242 - accuracy: 0.9277 - val_loss: 2.3641 - val_accuracy: 0.5196
# Epoch 46/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2398 - accuracy: 0.9234 - val_loss: 2.2966 - val_accuracy: 0.5220
# Epoch 47/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2239 - accuracy: 0.9274 - val_loss: 2.2556 - val_accuracy: 0.5373
# Epoch 48/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2052 - accuracy: 0.9343 - val_loss: 2.2693 - val_accuracy: 0.5270
# Epoch 49/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2107 - accuracy: 0.9299 - val_loss: 2.4662 - val_accuracy: 0.5317
# Epoch 50/50
# 628/628 [==============================] - 7s 11ms/step - loss: 0.2169 - accuracy: 0.9287 - val_loss: 2.3662 - val_accuracy: 0.5232

# %%
scores = model.evaluate(test_ds)
# Out:
# 225/225 [==============================] - 3s 5ms/step - loss: 2.3494 - accuracy: 0.5219

# %% [markdown]
# # Plot training history on graph

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label='Training accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label='Training loss')
plt.plot(range(EPOCHS), val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Training and Validation loss')

plt.show()

# %% [markdown]
# # Predictions on Sample images

# %%
# predict function takes model and image
def predict(model, img):
  img_array = tf.image.resize(img, (IMAGE_SIZE, IMAGE_SIZE))                    # resize the image (this line is for api) 
  img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())      # converts image to numpy array
  img_array = tf.expand_dims(img_array,0)

  predictions = model.predict(img_array)

  predicted_class = class_names[np.argmax(predictions[0])]                      # .argmax = returns index with highest argument
  confidence = round(100 * (np.max(predictions[0])), 2)                         # .max = returns highest argument

  return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype("uint8"))

    predicted_class, confidence = predict(model, images[i].numpy())
    actual_class = class_names[labels[i]]

    plt.title(f"Actual: {actual_class}\n Predicted: {predicted_class}\n Confidence: {confidence}%")
    plt.axis("off")

# %%
model_name = "emotion_recognizer"
model.save(f"./drive/MyDrive/Models/{model_name}")
# Out:
# INFO:tensorflow:Assets written to: ./drive/MyDrive/Models/emotion_recognizer/assets
